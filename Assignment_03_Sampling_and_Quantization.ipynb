# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def image_sampling(image, factor):
    return cv2.resize(image, dsize=(image.shape[1] // factor, image.shape[0] // factor), interpolation=cv2.INTER_LINEAR)

# Read the image
image = cv2.imread('/content/dog_image.jpeg')

# Display the original image
plt.figure(figsize=(8, 4))
plt.subplot(1, len(factors) + 1, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

# Downsampling with different factors
factors = [2, 4]  # Change factors as needed
for idx, factor in enumerate(factors):
    downsampled = image_sampling(image, factor)
    plt.subplot(1, len(factors) + 1, idx + 2)
    plt.imshow(cv2.cvtColor(downsampled, cv2.COLOR_BGR2RGB))
    plt.title(f'{factor}x Downsampled Image')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
def image_quantization(image, levels):
    div = 256 // levels
    return np.uint8(image // div * div)

# Read the image
image = cv2.imread('/content/dog_image.jpeg')

# Display the original image
plt.figure(figsize=(8, 4))
plt.subplot(1, len(quantization_levels) + 1, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

# Quantization with different levels
quantization_levels = [16,8,4]  # Change levels as needed
for idx, level in enumerate(quantization_levels):
    quantized = image_quantization(image, level)
    plt.subplot(1, len(quantization_levels) + 1, idx + 2)
    plt.imshow(cv2.cvtColor(quantized, cv2.COLOR_BGR2RGB))
    plt.title(f'{level} Levels')
    plt.axis('off')

plt.tight_layout()
plt.show()
